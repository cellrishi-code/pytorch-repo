# %% [markdown]
# <a href="https://colab.research.google.com/github/cellrishi-code/pytorch-repo/blob/main/07_07_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import math

# %%
a = torch.empty(2,3)

# %%
a   # initallied by the random value in the tensor
# Out:
# tensor([[3.6283e-37, 4.4238e-41, 5.6595e-19],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00]])

# %%
c = torch.tensor([1,6,-67,-25])

# %%
c.abs()
# Out:
# tensor([ 1,  6, 67, 25])

# %%
## actual praticng of autograd module in pytorch

# %%
x = torch.tensor(3.0, requires_grad=True)

# %%
y = x**2

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
x = torch.tensor(3.0, requires_grad=True)
y = torch.sin(x)
y.backward()
x.grad
# Out:
# tensor(-0.9900)

# %%
## simple neural newtrok building

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)  ## here in x , there is no required gard is true , we no need to find derivates wrt to x

# %%
w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# %%
z = w*x +b

# %%
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred = torch.sigmoid(z)

# %%
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
# Binary Cross-Entropy Loss for scalar
def binary_cross_entropy_loss(prediction, target):
    epsilon = 1e-8  # To prevent log(0)
    prediction = torch.clamp(prediction, epsilon, 1 - epsilon)
    return -(target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
loss = binary_cross_entropy_loss(y_pred,y)

# %%
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
## at once finding the derivates
w.grad
# Out:
# tensor(6.6918)

# %%
b.grad
# Out:
# tensor(0.9988)

# %%
x = torch.tensor([1.0,2.0,3.0], requires_grad=True)

# %%
y = (x**2).mean()

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
## clearing grad

# %%
x = torch.tensor(2.0, requires_grad=True)

# %%
y =x**2   ## this is called forward pass

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
x.grad.zero_()    ## here we are doing inplace 0 operation
# Out:
# tensor(0.)

# %%
## disable the gradient tracking in pytorch

# %% [markdown]
# 1. require_grad_ ==> do it false
# 2.detach()
# 3.torch.no_grad()
