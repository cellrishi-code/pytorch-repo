# %% [markdown]
# <a href="https://colab.research.google.com/github/cellrishi-code/pytorch-repo/blob/main/partdiff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## partial differntial in pytorch basic

# %%
import torch

# %%
x= torch.tensor([3.5,7.5,9.8] , requires_grad=True)

# %%
y = (x**2).mean()

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([2.3333, 5.0000, 6.5333])

# %%
x.grad.zero_()
# Out:
# tensor([0., 0., 0.])
